# %% [markdown]
# ### Parse Franka Emika `Panda`

# %%
import numpy as np
import matplotlib.pyplot as plt
from mujoco_parser import MuJoCoParserClass
np.set_printoptions(precision=2)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("Done.")
# Out:
# Done.

# %% [markdown]
# ### Parse `Panda`

# %%
env = MuJoCoParserClass(name='PAPRAS',rel_xml_path='../asset/papras/mjmodel.xml',VERBOSE=True)
# Out:
# [PAPRAS] Instantiated from [/Users/kazukishin/Workspace/papras-mujoco-usage/asset/papras/mjmodel.xml]
# - Simulation timestep is [0.0020]sec and frequency is [500]HZ
# - [PAPRAS] has [9] bodies
#  [00] body name:[world]
#  [01] body name:[robot1/link2]
#  [02] body name:[robot1/link3]
#  [03] body name:[robot1/link4]
#  [04] body name:[robot1/link5]
#  [05] body name:[robot1/link6]
#  [06] body name:[robot1/end_link]
#  [07] body name:[robot1/gripper_link]
#  [08] body name:[robot1/gripper_sub_link]
# - [PAPRAS] has [8] joints
#  [00] name:[robot1/joint1] type:[revolute] joint range:[-3.14 to 3.14]
#  [01] name:[robot1/joint2] type:[revolute] joint range:[-2.00 to 2.00]
#  [02] name:[robot1/joint3] type:[revolute] joint range:[-3.14 to 1.57]
#  [03] name:[robot1/joint4] type:[revolute] joint range:[-2.75 to 2.75]
#  [04] name:[robot1/joint5] type:[revolute] joint range:[-1.57 to 1.57]
#  [05] name:[robot1/joint6] type:[revolute] joint range:[-3.14 to 3.14]
#  [06] name:[robot1/gripper] type:[revolute] joint range:[0.00 to 1.15]
#  [07] name:[robot1/gripper_sub] type:[revolute] joint range:[0.00 to 1.15]
# - [PAPRAS] has [8] revolute joints
#  [00] joint index:[0] and name:[robot1/joint1]
#  [01] joint index:[1] and name:[robot1/joint2]
#  [02] joint index:[2] and name:[robot1/joint3]
#  [03] joint index:[3] and name:[robot1/joint4]
#  [04] joint index:[4] and name:[robot1/joint5]
#  [05] joint index:[5] and name:[robot1/joint6]
#  [06] joint index:[6] and name:[robot1/gripper]
#  [07] joint index:[7] and name:[robot1/gripper_sub]
# - [PAPRAS] has [8] actuators
#  [00] actuator name:[papras_torq_j1] torque range:[-80.00 to 80.00]
#  [01] actuator name:[papras_torq_j2] torque range:[-80.00 to 80.00]
#  [02] actuator name:[papras_torq_j3] torque range:[-80.00 to 80.00]
#  [03] actuator name:[papras_torq_j4] torque range:[-80.00 to 80.00]
#  [04] actuator name:[papras_torq_j5] torque range:[-80.00 to 80.00]
#  [05] actuator name:[papras_torq_j6] torque range:[-12.00 to 12.00]
#  [06] actuator name:[papras_gripper_finger_joint1] torque range:[0.00 to 0.04]
#  [07] actuator name:[papras_gripper_finger_joint2] torque range:[-0.04 to 0.00]
# - [PAPRAS] has [0] geometries

# %%
env.plot_scene(figsize=(8,4),title_str='Panda',title_fs=15)
# Out:
# Creating offscreen glfw

# %%
env.init_viewer(TERMINATE_GLFW=True,INITIALIZE_GLFW=True,window_width=0.5,window_height=0.5)
env.set_max_sec(max_sec=5.0)
env.reset()
while env.IS_ALIVE():
    torque = np.zeros(env.n_rev_joint) # zero torque
    env.step(ctrl=torque,ctrl_idxs=env.rev_joint_idxs) # torque applied to revolute joints
    env.render(render_speedup=1.0,RENDER_ALWAYS=False)
    env.print(print_every_sec=1.0,VERBOSE=1)
print ("Done.")
# Out:
# Creating window glfw
# Creating window glfw
# tick:[1/2500], sec_wall:[0.070]sec, sec_sim:[0.002]sec
# tick:[500/2500], sec_wall:[0.980]sec, sec_sim:[1.000]sec
# tick:[1000/2500], sec_wall:[1.998]sec, sec_sim:[2.000]sec
# tick:[1500/2500], sec_wall:[2.997]sec, sec_sim:[3.000]sec
# tick:[2000/2500], sec_wall:[3.997]sec, sec_sim:[4.000]sec
# tick:[2500/2500], sec_wall:[4.999]sec, sec_sim:[5.000]sec
# Done.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
env.init_viewer(INITIALIZE_GLFW=True)
env.plot_scene(figsize=(8,4),title_str='Panda',title_fs=15)
# Out:
# Creating window glfw

# %%
env.terminate_viewer()
